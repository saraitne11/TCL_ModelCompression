# %%
import torchvision
import json
import os

# %%
IMAGENET_DIR = '/home/data/ImageNet'

# %%
with open(os.path.join(IMAGENET_DIR, 'imagenet.json')) as f:
    imagenet_labels = json.load(f)

# %%
dataset = torchvision.datasets.ImageNet(root=IMAGENET_DIR, split='val')

# %%
len(dataset)
# Out:
# 50000

# %%
x, y = dataset[7777]

# %%
print(x) 
print(y)
print(imagenet_labels[y])
display(x)
# Out:
# <PIL.Image.Image image mode=RGB size=500x375 at 0x7F214AA29AF0>
# 155
# Shih-Tzu
# <PIL.Image.Image image mode=RGB size=500x375>
